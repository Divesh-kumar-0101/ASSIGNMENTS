# %% [markdown]
# ## 1) Types of Applications

# %% [markdown]
# Desktop applications, Web applications, Mobile applications, Console applications, Embedded systems, Data science & AI applications, Game applications.

# %% [markdown]
# ## 2) What is Programming?

# %% [markdown]
# Programming is the process of designing, writing, testing, and maintaining instructions (code) that a computer follows to perform tasks.

# %% [markdown]
# ## 3) What is Python?

# %% [markdown]
# Python is a high-level, interpreted, object-oriented programming language known for simplicity and readability.

# %% [markdown]
# ## 4) Check positive, negative or zero

# %%
num = int(input("Enter number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# %% [markdown]
# ## 5) Factorial of a number

# %%
n = int(input("Enter number: "))
fact = 1
for i in range(1, n+1):
    fact *= i
print(fact)

# %% [markdown]
# ## 6) Fibonacci series

# %%
n = int(input("Enter range: "))
a, b = 0, 1
for _ in range(n):
    print(a, end=" ")
    a, b = b, a + b

# %% [markdown]
# ## 7) Memory Management in Python

# %% [markdown]
# Python uses automatic memory management with garbage collection and reference counting.

# %% [markdown]
# ## 8) Purpose of continue statement

# %% [markdown]
# `continue` skips the current iteration and continues with the next iteration of the loop.

# %% [markdown]
# ## 9) Swap numbers

# %%
# With temp
a, b = 5, 10
temp = a
a = b
b = temp
print(a, b)

# Without temp
a, b = b, a
print(a, b)

# %% [markdown]
# ## 10) Even or Odd

# %%
n = int(input("Enter number: "))
print("Even" if n % 2 == 0 else "Odd")

# %% [markdown]
# ## 11) Vowel check

# %%
ch = input("Enter character: ").lower()
print("Vowel" if ch in "aeiou" else "Not Vowel")

# %% [markdown]
# ## 12) Sum of three integers

# %%
a, b, c = 1, 2, 2
print(0 if a == b or b == c or a == c else a + b + c)

# %% [markdown]
# ## 13) Equal or sum/difference is 5

# %%
a, b = 3, 2
print(a == b or a + b == 5 or abs(a - b) == 5)

# %% [markdown]
# ## 14) Sum of first n positive integers

# %%
n = int(input("Enter n: "))
print(n * (n + 1) // 2)

# %% [markdown]
# ## 15) Length of string

# %%
s = input("Enter string: ")
print(len(s))

# %% [markdown]
# ## 16) Character frequency

# %%
s = "hello"
freq = {}
for ch in s:
    freq[ch] = freq.get(ch, 0) + 1
print(freq)

# %% [markdown]
# ## 17) Negative Indexes

# %% [markdown]
# Negative indexes access elements from the end of a sequence (e.g., -1 is last element).

# %% [markdown]
# ## 18) Count substring

# %%
s = "hello hello"
sub = "hello"
print(s.count(sub))

# %% [markdown]
# ## 19) Word frequency in sentence

# %%
sentence = "this is a test this is python"
words = sentence.split()
freq = {}
for w in words:
    freq[w] = freq.get(w, 0) + 1
print(freq)

# %% [markdown]
# ## 20) Swap first two characters

# %%
a, b = "abc", "xyz"
new = b[:2] + a[2:] + " " + a[:2] + b[2:]
print(new)

# %% [markdown]
# ## 21) Add ing / ly

# %%
s = "play"
if len(s) < 3:
    print(s)
elif s.endswith("ing"):
    print(s + "ly")
else:
    print(s + "ing")

# %% [markdown]
# ## 22) Reverse string if multiple of 4

# %%
def rev_if_4(s):
    return s[::-1] if len(s) % 4 == 0 else s

print(rev_if_4("abcd"))

# %% [markdown]
# ## 23) First 2 and last 2 chars

# %%
s = "python"
print(s[:2] + s[-2:] if len(s) >= 2 else "")

# %% [markdown]
# ## 24) Insert string in middle

# %%
def insert_mid(a, b):
    mid = len(a) // 2
    return a[:mid] + b + a[mid:]

print(insert_mid("<<>>", "Python"))

# %% [markdown]
# ## 25) List and reverse

# %% [markdown]
# List is a mutable ordered collection.

# %%
lst = [1, 2, 3]
print(lst[::-1])

# %% [markdown]
# ## 26) Remove last object

# %%
lst.pop()
print(lst)

# %% [markdown]
# ## 27) list1[-1]

# %% [markdown]
# It returns the last element: 25

# %% [markdown]
# ## 28) append vs extend

# %% [markdown]
# append() adds one element, extend() adds multiple elements from another iterable.

# %% [markdown]
# ## 29) Largest, smallest, sum

# %%
lst = [1, 2, 3, 4]
print(max(lst), min(lst), sum(lst))

# %% [markdown]
# ## 30) Compare two lists

# %% [markdown]
# Using == operator or looping element-wise.

# %% [markdown]
# ## 31) Count strings with same first & last char

# %%
lst = ["aba", "xyz", "aa", "x"]
count = 0
for s in lst:
    if len(s) >= 2 and s[0] == s[-1]:
        count += 1
print(count)

# %% [markdown]
# ## 32) Remove duplicates

# %%
lst = [1, 2, 2, 3]
print(list(set(lst)))

# %% [markdown]
# ## 33) Check empty list

# %%
lst = []
print("Empty" if not lst else "Not Empty")

# %% [markdown]
# ## 34) Common member

# %%
def common(a, b):
    return bool(set(a) & set(b))

print(common([1,2], [2,3]))

# %% [markdown]
# ## 35) Squares list

# %%
lst = [i*i for i in range(1, 31)]
print(lst[:5] + lst[-5:])

# %% [markdown]
# ## 36) Unique elements

# %%
def unique(lst):
    return list(set(lst))

print(unique([1,2,2,3]))

# %% [markdown]
# ## 37) List of chars to string

# %%
chars = ['p','y','t','h','o','n']
print("".join(chars))

# %% [markdown]
# ## 38) Random item from list

# %%
import random
print(random.choice([1,2,3,4]))

# %% [markdown]
# ## 39) Second smallest

# %%
lst = [1, 2, 3, 4]
print(sorted(lst)[1])

# %% [markdown]
# ## 40) Unique values from list

# %%
print(list(set([1,1,2,3])))

# %% [markdown]
# ## 41) Sublist check

# %%
a = [1,2,3,4]
b = [2,3]
print(all(x in a for x in b))

# %% [markdown]
# ## 42) Split list into variables

# %%
lst = [1,2,3]
a, b, c = lst
print(a, b, c)

# %% [markdown]
# ## 43) Tuple and difference

# %% [markdown]
# Tuple is immutable. List is mutable.

# %% [markdown]
# ## 44) Tuple with different data types

# %%
t = (1, "Python", 3.5)
print(t)

# %% [markdown]
# ## 45) Unzip list of tuples

# %%
lst = [(1,2), (3,4)]
a, b = zip(*lst)
print(a, b)

# %% [markdown]
# ## 46) List of tuples to dictionary

# %%
lst = [("a",1), ("b",2)]
print(dict(lst))

# %% [markdown]
# ## 47) Create dictionary using tuples

# %% [markdown]
# Use dict() constructor.

# %% [markdown]
# ## 48) Sort dictionary by value

# %%
d = {'a':3,'b':1,'c':2}
print(dict(sorted(d.items(), key=lambda x: x[1])))
print(dict(sorted(d.items(), key=lambda x: x[1], reverse=True)))

# %% [markdown]
# ## 49) Concatenate dictionaries

# %%
d1 = {'a':1}
d2 = {'b':2}
d1.update(d2)
print(d1)

# %% [markdown]
# ## 50) Key exists or not

# %%
d = {'a':1}
print('a' in d)

# %% [markdown]
# ## 51) Traverse dictionary

# %% [markdown]
# Using for key, value in dict.items().

# %% [markdown]
# ## 52) Check presence of key

# %% [markdown]
# Using `in` keyword.

# %% [markdown]
# ## 53) Dictionary 1 to 15

# %%
print({i: i*i for i in range(1,16)})

# %% [markdown]
# ## 54) Multiple keys exist

# %%
d = {'a':1,'b':2}
print(all(k in d for k in ['a','b']))

# %% [markdown]
# ## 55) Merge dictionaries

# %%
d1 = {'a':1}
d2 = {'b':2}
print({**d1, **d2})

# %% [markdown]
# ## 56) Map two lists to dictionary

# %%
keys = ['a','b','c']
values = [400,400,300]
print(dict(zip(keys, values)))

# %% [markdown]
# ## 57) Highest 3 values in dictionary

# %%
d = {'a':10,'b':30,'c':20,'d':40}
print(sorted(d.values(), reverse=True)[:3])

# %% [markdown]
# ## 58) Combine values in list of dictionaries

# %%
from collections import Counter
data = [{'item':'item1','amount':400},
        {'item':'item2','amount':300},
        {'item':'item1','amount':750}]
c = Counter()
for d in data:
    c[d['item']] += d['amount']
print(c)

# %% [markdown]
# ## 59 & 60) Dictionary from string

# %%
from collections import Counter
s = "w3resource"
print(dict(Counter(s)))

# %% [markdown]
# ## 61) Factorial function

# %%
def factorial(n):
    return 1 if n == 0 else n * factorial(n-1)

print(factorial(5))

# %% [markdown]
# ## 62) Number in range

# %%
def in_range(n, start, end):
    return start <= n <= end

print(in_range(5,1,10))

# %% [markdown]
# ## 63) Perfect number

# %%
def perfect(n):
    return n == sum(i for i in range(1, n) if n % i == 0)

print(perfect(6))

# %% [markdown]
# ## 64) Palindrome check

# %%
def palindrome(s):
    return s == s[::-1]

print(palindrome("madam"))

# %% [markdown]
# ## 65) Types of functions

# %% [markdown]
# Built-in functions and User-defined functions.

# %% [markdown]
# ## 66) Random item from list/tuple

# %% [markdown]
# Use random.choice().

# %% [markdown]
# ## 67) Random item from range

# %% [markdown]
# Use random.randrange().

# %% [markdown]
# ## 68) Random number

# %% [markdown]
# Use random.random() or random.randint().

# %% [markdown]
# ## 69) Set starting value for random

# %% [markdown]
# Use random.seed().

# %% [markdown]
# ## 70) Randomize list

# %%
import random
lst = [1,2,3,4]
random.shuffle(lst)
print(lst)

# %% [markdown]
# ## 71) File functions

# %% [markdown]
# open() function. Modes: r, w, a.

# %% [markdown]
# ## 72) Read entire file

# %%
with open("sample.txt","r") as f:
    print(f.read())

# %% [markdown]
# ## 73) Append to file

# %%
with open("sample.txt","a") as f:
    f.write("Hello")

# %% [markdown]
# ## 74) Read first n lines

# %%
n = 2
with open("sample.txt") as f:
    for i in range(n):
        print(f.readline())

# %% [markdown]
# ## 75) Read last n lines

# %% [markdown]
# Use readlines() and slicing.

# %% [markdown]
# ## 76) File to list

# %% [markdown]
# Use readlines().

# %% [markdown]
# ## 77) File to variable

# %% [markdown]
# Use read().

# %% [markdown]
# ## 78) Longest word

# %%
words = ["python","java","javascript"]
print(max(words, key=len))

# %% [markdown]
# ## 79) Count lines

# %%
with open("sample.txt") as f:
    print(len(f.readlines()))

# %% [markdown]
# ## 80) Word frequency in file

# %% [markdown]
# Use Counter with split().

# %% [markdown]
# ## 81) Write list to file

# %%
lst = ["a","b","c"]
with open("out.txt","w") as f:
    for item in lst:
        f.write(item + "\n")

# %% [markdown]
# ## 82) Copy file

# %% [markdown]
# Read source and write to destination.

# %% [markdown]
# ## 83) Exception handling

# %% [markdown]
# Handling runtime errors using try-except blocks.

# %% [markdown]
# ## 84) Except statements

# %% [markdown]
# Multiple except blocks allowed. Examples: ValueError, TypeError.

# %% [markdown]
# ## 85) try-except-else

# %% [markdown]
# Else runs if no exception occurs.

# %% [markdown]
# ## 86) Multiple exceptions

# %% [markdown]
# Yes, using tuple in except.

# %% [markdown]
# ## 87) finally block

# %% [markdown]
# Always executed.

# %% [markdown]
# ## 88) '1' == 1

# %% [markdown]
# Returns False (string vs integer).

# %% [markdown]
# ## 89) Try/Except/Finally example

# %%
try:
    x = int("abc")
except ValueError:
    print("Error occurred")
finally:
    print("Done")

# %% [markdown]
# ## 90) Only odd numbers

# %%
try:
    n = int(input("Enter odd number: "))
    if n % 2 == 0:
        raise ValueError("Even number entered")
    print("Valid odd number")
except ValueError as e:
    print(e)
